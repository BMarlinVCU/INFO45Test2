# %% [markdown]
# <a href="https://colab.research.google.com/github/BMarlinVCU/INFO45Test2/blob/main/lesson3/133.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
response=requests.get("https://catfact.ninja/fact")

# %%
response.json()

# %%
data=response.json()

# %%
data

# %%
data['fact']

# %% [markdown]
# Lets do the world cup.

# %%
import urllib.request
import json

# Fetch the data (like opening a URL)
url = "https://raw.githubusercontent.com/openfootball/worldcup.json/master/2026/worldcup.json"
response = requests.get(url)
data = response.json()
data
# data is now a Python dictionary!
#print(type(data))        # <class 'dict'>
#print(data.keys())       # see what's inside
data['matches']
#data['matches'][55]
#data['matches'][55]['team1']

# Look at the first match
#first_match = data["matches"][0]


# Access specific fields
#print(first_match["date"])
#print(first_match["team1"]["name"])
#print(first_match["team2"]["name"])

# %%
import requests
import json

url = "https://raw.githubusercontent.com/BMarlinVCU/partstestINFO450/main/parts.json"
response = requests.get(url)

# %%
data=response.json()

# %%
data['parts'][1]['name']
# Out:
# 'Motherboard'

# %%
response=requests.get("https://raw.githubusercontent.com/BMarlinVCU/INFO45Test2/main/parts.json")

# %%
response.json()
# Out:
# {'parts': [{'id': 1,
#    'name': 'CPU',
#    'brand': 'Generic',
#    'category': 'Processor',
#    'cost': 189.99},
#   {'id': 2,
#    'name': 'Motherboard',
#    'brand': 'Generic',
#    'category': 'Board',
#    'cost': 124.99},
#   {'id': 3,
#    'name': 'RAM 8GB',
#    'brand': 'Generic',
#    'category': 'Memory',
#    'cost': 34.99},
#   {'id': 4,
#    'name': 'RAM 16GB',
#    'brand': 'Generic',
#    'category': 'Memory',
#    'cost': 59.99},
#   {'id': 5,
#    'name': 'SSD 256GB',
#    'brand': 'Generic',
#    'category': 'Storage',
#    'cost': 44.99},
#   {'id': 6,
#    'name': 'SSD 512GB',
#    'brand': 'Generic',
#    'category': 'Storage',
#    'cost': 74.99},
#   {'id': 7,
#    'name': 'HDD 1TB',
#    'brand': 'Generic',
#    'category': 'Storage',
#    'cost': 49.99},
#   {'id': 8,
#    'name': 'GPU',
#    'brand': 'Generic',
#    'category': 'Graphics',
#    'cost': 299.99},
#   {'id': 9,
#    'name': 'Power Supply 500W',
#    'brand': 'Generic',
# ...
